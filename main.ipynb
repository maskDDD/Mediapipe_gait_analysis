# %%
from preprocessing import PREPROCESS
from graph import write_graph
import os

rootPath = os.getcwd()
marker_filename = "new0904_normal1.csv"
markerless_filename = "IMG_6797.csv"


prepre = PREPROCESS(rootPath, marker_filename, markerless_filename)
marker, markerless = prepre.make_complite()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 16
#      14 graph = write_graph(marker, markerless , "HEEL", "h")
#      15 graph.visualize()
# ---> 16 graph.differential()
#
# AttributeError: 'write_graph' object has no attribute 'differential'

# %%
# 높이는 h, 너비는 w
graph = write_graph(marker, markerless , "HEEL", "h")
graph.visualize()
graph.differential()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 높이는 h, 너비는 w
# ----> 2 graph = write_graph(marker, markerless , "HEEL", "h")
#       3 graph.visualize()
#       4 graph.differential()
#
# NameError: name 'write_graph' is not defined
