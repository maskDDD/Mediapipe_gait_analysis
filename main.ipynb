# %%
from preprocessing import PREPROCESS
from graph import write_graph
from angle import Angle
import os

rootPath = os.getcwd()
#경로는 rootPath에서 어디에 있는지 적으세요
marker_filename = "\\marker_fin_csv\\0912_poster\\3m\\S001_3.csv"
markerless_filename = "\\markerless_raw_csv\\0912_poster\\S001\\S001_3.csv"


prepre = PREPROCESS(rootPath, marker_filename, markerless_filename)
marker, markerless = prepre.make_complite()

# %%
# 높이는 h, 너비는 w
graph = write_graph(marker, markerless , "HEEL", "h")
graph.visualize()
graph.differential()    # 미분

# %%
angle = Angle(marker, markerless)
angle.visualize("right_knee_flexion_2d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 angle = Angle(marker, markerless)
# ----> 2 angle.visualize()
#
# TypeError: Angle.visualize() missing 1 required positional argument: 'object'

# %%
graph.feature_extraction()
# Out:
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 graph.feature_extraction()
#
# File c:\PHYNIX_PKNU\graph.py:118, in write_graph.feature_extraction(self)
#     116 print(L_HEEL_EV1)
#     117 L_HEEL_EV2=L_HEEL[whL[1]:whR[1]]
# --> 118 L_HEEL_EV1_ml_min=L_HEEL_EV1.index(min(L_HEEL_EV1))
#     119 L_HEEL_EV2_ml_min=L_HEEL_EV2.index(min(L_HEEL_EV2))
#     120 L_HEEL_EV1_ml_min=L_HEEL_EV1_ml_min+whL[0]+1
#
# ValueError: min() iterable argument is empty
