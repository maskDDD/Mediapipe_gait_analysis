# %%
from preprocessing import PREPROCESS
from graph import write_graph
import os

rootPath = os.getcwd()
marker_filename = "normal1.CSV"
markerless_filename = "IMG_6840.csv"


prepre = PREPROCESS(rootPath, marker_filename, markerless_filename)
marker, markerless = prepre.make_complite()
# Out:
# c:\Users\qqppq\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
# 높이는 h, 너비는 w
graph = write_graph(marker, markerless , "HEEL", "w")
graph.visualize()
graph.differential()    # 미분

# %%
graph.feature_extraction()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 graph.feature_extraction()
#
# File c:\PHYNIX_PKNU\graph.py:130, in write_graph.feature_extraction(self)
#     127         wr_flagL=0
#     129 L_HEEL=list(self.markerless[self.landmark_marker_L])
# --> 130 L_HEEL_EV1=L_HEEL[whL[0]:whR[0]]
#     131 L_HEEL_EV2=L_HEEL[whL[1]:whR[1]]
#     132 L_HEEL_EV1_ml_min=L_HEEL_EV1.index(min(L_HEEL_EV1))
#
# IndexError: list index out of range
